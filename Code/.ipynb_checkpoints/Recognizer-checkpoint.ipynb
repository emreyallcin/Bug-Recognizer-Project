# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import os
import librosa
import numpy as np
import soundfile as sf
import sounddevice as sd
import h5py
import matplotlib.image as mpimg

from tqdm import tqdm
from pathlib import Path
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, roc_auc_score
from datetime import datetime

# %%
current_dir = os.getcwd()
base_dir = os.path.dirname(current_dir)

# %%
def augment_audio(audio, sample_rate):
    pitch_shifted = librosa.effects.pitch_shift(audio, sr=sample_rate, n_steps=np.random.uniform(-2, 2))
    time_stretched = librosa.effects.time_stretch(audio, rate=np.random.uniform(0.8, 1.2))
    noise = np.random.randn(len(audio))
    noise_added = audio + 0.005 * noise
    return [pitch_shifted, time_stretched, noise_added]

# %%
def feature_extractor(audio, sample_rate):
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=20)
    mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
    return mfccs_scaled_features

# %%
def record_audio(duration=6, fs=22050):
    print("Recording...")
    audio = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='float32')
    sd.wait()
    print("Recording complete.")
    audio = audio.flatten()
    return audio, fs

# %%
def classify_sound(audio, threshold=0.5):
    mfcc_features = feature_extractor(audio, recorded_sample_rate)
    mfccs_scaled_features = mfcc_features.reshape(1, -1)
    result_array = model.predict(mfccs_scaled_features)
    result_index = np.argmax(result_array)
    confidence = result_array[0][result_index]
    if confidence < threshold:
        return "Non-bug Sound"
    else:
        return result_bugs[result_index]

# %%
audio_dataset_path = os.path.join(base_dir, "Database/audio")
metadata_path = os.path.join(base_dir, "Database/metadata/BugSounds.csv")
metadata = pd.read_csv(metadata_path)

# %%
known_insects = set(["Bee", "Beetle", "Bess Beetle", "Bumblebee", "Butterfly", "Click Beetle", "Cockroach", "Cricket", "Dor Beetle", "Dragonfly", "Dung Beetle", "Grasshopper", "House Fly", "Katydid", "Locust", "Long Horn Beetle", "Mole Cricket", "Mosquito", "Moth", "Wasp"])

# %%
metadata['bug_name'] = metadata['bug_name'].apply(lambda x: x if x in known_insects else 'non_bug')

# %%
extracted_features = []
for index_num, row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path), str(row["file_name"]))
    final_class_labels = row["bug_name"]
    audio, sample_rate = librosa.load(file_name, res_type="kaiser_fast")
    data = feature_extractor(audio, sample_rate)
    extracted_features.append([data, final_class_labels])
    augmented_audios = augment_audio(audio, sample_rate)
    for aug_audio in augmented_audios:
        mfccs_features = librosa.feature.mfcc(y=aug_audio, sr=sample_rate, n_mfcc=20)
        mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
        extracted_features.append([mfccs_scaled_features, final_class_labels])
# Out:
# 20it [00:07,  2.54it/s]

# %%
extracted_features_df = pd.DataFrame(extracted_features, columns=["features", "bug"])

# %%
x = np.array(extracted_features_df["features"].tolist())
y = np.array(extracted_features_df["bug"].tolist())

# %%
labelencoder = LabelEncoder()
y_encoded = labelencoder.fit_transform(y)

# %%
num_classes = len(labelencoder.classes_)
y = to_categorical(y_encoded, num_classes=num_classes)

# %%
test_size = max(0.2, num_classes / len(y))

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=test_size, random_state=42, stratify=y_encoded)

# %%
model=Sequential()
model.add(Dense(64,input_shape=(20,)))
model.add(Activation("relu"))
model.add(Dropout(0.5))
# Hidden
model.add(Dense(32))
model.add(Activation("relu"))
model.add(Dropout(0.5))
# Output
model.add(Dense(num_classes))
model.add(Activation("softmax"))
# Out:
# C:\Anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 20)             │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 20)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,084 (15.95 KB)
#  Trainable params: 4,084 (15.95 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=Adam(learning_rate=0.001))

# %%
epochscount=1000
num_batch_size=4

# %%
model.fit(xtrain, ytrain, batch_size=num_batch_size, epochs=epochscount, validation_data=(xtest, ytest), verbose=1)
# Out:
# Epoch 1/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9493 - loss: 0.2502 - val_accuracy: 0.9000 - val_loss: 0.3246
# Epoch 2/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8012 - loss: 0.8447 - val_accuracy: 0.9000 - val_loss: 0.2571
# Epoch 3/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.3943 - val_accuracy: 0.9000 - val_loss: 0.2434
# Epoch 4/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8071 - loss: 0.4507 - val_accuracy: 0.8500 - val_loss: 0.2408
# Epoch 5/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8825 - loss: 0.2900 - val_accuracy: 0.8500 - val_loss: 0.2474
# Epoch 6/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8832 - loss: 0.2213 - val_accuracy: 0.9000 - val_loss: 0.2511
# Epoch 7/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9222 - loss: 0.2833 - val_accuracy: 0.9000 - val_loss: 0.2673
# Epoch 8/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9408 - loss: 0.3860 - val_accuracy: 0.9500 - val_loss: 0.2964
# Epoch 9/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8278 - loss: 0.6622 - val_accuracy: 0.9500 - val_loss: 0.3458
# Epoch 10/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8127 - loss: 1.3637 - val_accuracy: 0.9500 - val_loss: 0.3498
# Epoch 11/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9108 - loss: 0.3045 - val_accuracy: 0.9500 - val_loss: 0.3602
# Epoch 12/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9374 - loss: 0.1563 - val_accuracy: 0.9500 - val_loss: 0.3838
# Epoch 13/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8573 - loss: 0.4794 - val_accuracy: 0.9000 - val_loss: 0.4179
# Epoch 14/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8091 - loss: 0.5528 - val_accuracy: 0.8000 - val_loss: 0.4423
# Epoch 15/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8475 - loss: 0.5080 - val_accuracy: 0.8000 - val_loss: 0.4489
# Epoch 16/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8680 - loss: 0.3015 - val_accuracy: 0.8000 - val_loss: 0.5324
# Epoch 17/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8543 - loss: 0.5130 - val_accuracy: 0.8000 - val_loss: 0.4864
# Epoch 18/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7998 - loss: 0.4467 - val_accuracy: 0.8500 - val_loss: 0.5248
# Epoch 19/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8697 - loss: 0.4469 - val_accuracy: 0.8500 - val_loss: 0.6215
# Epoch 20/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8905 - loss: 0.3579 - val_accuracy: 0.8500 - val_loss: 0.7102
# Epoch 21/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8093 - loss: 0.7692 - val_accuracy: 0.8500 - val_loss: 0.7045
# Epoch 22/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7896 - loss: 0.3906 - val_accuracy: 0.8000 - val_loss: 0.7427
# Epoch 23/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9561 - loss: 0.2098 - val_accuracy: 0.8000 - val_loss: 0.8250
# Epoch 24/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8826 - loss: 0.7982 - val_accuracy: 0.8500 - val_loss: 0.7571
# Epoch 25/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8182 - loss: 0.4808 - val_accuracy: 0.8500 - val_loss: 0.7642
# Epoch 26/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7212 - loss: 0.9230 - val_accuracy: 0.9000 - val_loss: 0.5864
# Epoch 27/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9072 - loss: 0.3394 - val_accuracy: 0.9000 - val_loss: 0.6445
# Epoch 28/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8776 - loss: 0.4460 - val_accuracy: 0.9000 - val_loss: 0.6951
# Epoch 29/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8112 - loss: 0.6913 - val_accuracy: 0.9000 - val_loss: 0.7233
# Epoch 30/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9421 - loss: 0.1871 - val_accuracy: 0.9000 - val_loss: 0.7540
# Epoch 31/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9014 - loss: 0.5392 - val_accuracy: 0.9000 - val_loss: 0.7414
# Epoch 32/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8521 - loss: 0.3393 - val_accuracy: 0.9000 - val_loss: 0.6357
# Epoch 33/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7486 - loss: 0.6536 - val_accuracy: 0.9000 - val_loss: 0.5620
# Epoch 34/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8296 - loss: 0.4799 - val_accuracy: 0.9000 - val_loss: 0.6304
# Epoch 35/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8231 - loss: 0.3917 - val_accuracy: 0.9000 - val_loss: 0.6003
# Epoch 36/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8458 - loss: 0.3455 - val_accuracy: 0.9000 - val_loss: 0.5027
# Epoch 37/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8642 - loss: 0.3935 - val_accuracy: 0.9000 - val_loss: 0.4428
# Epoch 38/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8200 - loss: 0.4452 - val_accuracy: 0.9000 - val_loss: 0.4817
# Epoch 39/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7964 - loss: 0.7789 - val_accuracy: 0.9000 - val_loss: 0.5227
# Epoch 40/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8295 - loss: 0.6320 - val_accuracy: 0.9000 - val_loss: 0.5582
# Epoch 41/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8536 - loss: 0.4502 - val_accuracy: 0.9000 - val_loss: 0.5589
# Epoch 42/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8979 - loss: 0.4410 - val_accuracy: 0.9000 - val_loss: 0.5534
# Epoch 43/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8842 - loss: 0.3833 - val_accuracy: 0.9000 - val_loss: 0.5618
# Epoch 44/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9071 - loss: 0.2753 - val_accuracy: 0.9000 - val_loss: 0.5718
# Epoch 45/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9007 - loss: 0.2586 - val_accuracy: 0.9000 - val_loss: 0.5544
# Epoch 46/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8220 - loss: 0.5062 - val_accuracy: 0.9000 - val_loss: 0.6019
# Epoch 47/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8700 - loss: 0.7145 - val_accuracy: 0.9000 - val_loss: 0.6671
# Epoch 48/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9087 - loss: 0.2544 - val_accuracy: 0.9000 - val_loss: 0.6700
# Epoch 49/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7351 - loss: 0.7207 - val_accuracy: 0.9000 - val_loss: 0.6011
# Epoch 50/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8657 - loss: 0.3791 - val_accuracy: 0.9000 - val_loss: 0.5741
# Epoch 51/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8035 - loss: 0.9460 - val_accuracy: 0.9000 - val_loss: 0.6016
# Epoch 52/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7903 - loss: 1.1254 - val_accuracy: 0.9500 - val_loss: 0.5659
# Epoch 53/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9063 - loss: 0.2847 - val_accuracy: 0.9500 - val_loss: 0.5534
# Epoch 54/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8062 - loss: 0.7004 - val_accuracy: 0.9500 - val_loss: 0.5617
# Epoch 55/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9452 - loss: 0.1687 - val_accuracy: 0.9500 - val_loss: 0.4687
# Epoch 56/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8970 - loss: 0.3753 - val_accuracy: 0.9000 - val_loss: 0.4261
# Epoch 57/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8807 - loss: 0.3759 - val_accuracy: 0.9000 - val_loss: 0.4152
# Epoch 58/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8637 - loss: 0.3909 - val_accuracy: 0.9500 - val_loss: 0.3886
# Epoch 59/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8777 - loss: 0.6276 - val_accuracy: 0.9500 - val_loss: 0.3604
# Epoch 60/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8143 - loss: 0.6568 - val_accuracy: 0.9500 - val_loss: 0.3356
# Epoch 61/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8693 - loss: 0.3521 - val_accuracy: 0.9500 - val_loss: 0.3114
# Epoch 62/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7663 - loss: 0.5017 - val_accuracy: 0.9500 - val_loss: 0.3062
# Epoch 63/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8060 - loss: 0.5614 - val_accuracy: 0.9500 - val_loss: 0.3281
# Epoch 64/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8540 - loss: 0.3911 - val_accuracy: 0.9500 - val_loss: 0.3895
# Epoch 65/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8978 - loss: 0.7099 - val_accuracy: 0.9500 - val_loss: 0.4683
# Epoch 66/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9118 - loss: 0.2456 - val_accuracy: 0.9500 - val_loss: 0.4959
# Epoch 67/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8840 - loss: 0.4411 - val_accuracy: 0.9000 - val_loss: 0.5777
# Epoch 68/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8838 - loss: 0.3269 - val_accuracy: 0.9000 - val_loss: 0.7211
# Epoch 69/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8235 - loss: 0.4703 - val_accuracy: 0.9000 - val_loss: 0.6490
# Epoch 70/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7700 - loss: 0.7011 - val_accuracy: 0.9000 - val_loss: 0.6491
# Epoch 71/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8142 - loss: 0.6140 - val_accuracy: 0.9000 - val_loss: 0.4665
# Epoch 72/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8368 - loss: 0.4939 - val_accuracy: 0.9000 - val_loss: 0.4301
# Epoch 73/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.4457 - val_accuracy: 0.9000 - val_loss: 0.4892
# Epoch 74/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7824 - loss: 0.7586 - val_accuracy: 0.9000 - val_loss: 0.6514
# Epoch 75/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8613 - loss: 0.2615 - val_accuracy: 0.9000 - val_loss: 0.6919
# Epoch 76/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8719 - loss: 0.4245 - val_accuracy: 0.9000 - val_loss: 0.7159
# Epoch 77/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8374 - loss: 0.7099 - val_accuracy: 0.9000 - val_loss: 0.6832
# Epoch 78/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8819 - loss: 0.2715 - val_accuracy: 0.9000 - val_loss: 0.5785
# Epoch 79/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8315 - loss: 0.7794 - val_accuracy: 0.9000 - val_loss: 0.3107
# Epoch 80/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8196 - loss: 0.6754 - val_accuracy: 0.9000 - val_loss: 0.3118
# Epoch 81/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.6690 - val_accuracy: 0.9000 - val_loss: 0.3496
# Epoch 82/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8518 - loss: 0.4888 - val_accuracy: 0.8500 - val_loss: 0.3527
# Epoch 83/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8875 - loss: 0.4393 - val_accuracy: 0.8500 - val_loss: 0.3908
# Epoch 84/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.3071 - val_accuracy: 0.8500 - val_loss: 0.3771
# Epoch 85/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8971 - loss: 0.3625 - val_accuracy: 0.8500 - val_loss: 0.3579
# Epoch 86/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8905 - loss: 0.3536 - val_accuracy: 0.9000 - val_loss: 0.2700
# Epoch 87/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8176 - loss: 0.5464 - val_accuracy: 0.9000 - val_loss: 0.2525
# Epoch 88/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8383 - loss: 0.7636 - val_accuracy: 0.9000 - val_loss: 0.2743
# Epoch 89/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9088 - loss: 0.4278 - val_accuracy: 0.9000 - val_loss: 0.2273
# Epoch 90/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7617 - loss: 1.3028 - val_accuracy: 0.9000 - val_loss: 0.2502
# Epoch 91/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8816 - loss: 0.3520 - val_accuracy: 0.9000 - val_loss: 0.3539
# Epoch 92/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8625 - loss: 0.3219 - val_accuracy: 0.9000 - val_loss: 0.4298
# Epoch 93/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7526 - loss: 1.2880 - val_accuracy: 0.9500 - val_loss: 0.4697
# Epoch 94/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8107 - loss: 0.8507 - val_accuracy: 0.9500 - val_loss: 0.4787
# Epoch 95/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8367 - loss: 0.3856 - val_accuracy: 0.9000 - val_loss: 0.2096
# Epoch 96/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9000 - loss: 0.3848 - val_accuracy: 0.9000 - val_loss: 0.2307
# Epoch 97/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9089 - loss: 0.3738 - val_accuracy: 0.9000 - val_loss: 0.2529
# Epoch 98/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9606 - loss: 0.1031 - val_accuracy: 0.9000 - val_loss: 0.2143
# Epoch 99/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9525 - loss: 0.1381 - val_accuracy: 0.8500 - val_loss: 0.2047
# Epoch 100/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8999 - loss: 0.3383 - val_accuracy: 0.8500 - val_loss: 0.2009
# Epoch 101/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8611 - loss: 0.4951 - val_accuracy: 0.8500 - val_loss: 0.2172
# Epoch 102/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8679 - loss: 0.4487 - val_accuracy: 0.8500 - val_loss: 0.2219
# Epoch 103/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.3120 - val_accuracy: 0.9000 - val_loss: 0.2293
# Epoch 104/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8860 - loss: 0.3432 - val_accuracy: 0.9000 - val_loss: 0.2843
# Epoch 105/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9120 - loss: 0.3487 - val_accuracy: 0.9000 - val_loss: 0.3543
# Epoch 106/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8663 - loss: 0.3754 - val_accuracy: 0.9000 - val_loss: 0.3861
# Epoch 107/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9028 - loss: 0.2653 - val_accuracy: 0.8500 - val_loss: 0.3944
# Epoch 108/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9256 - loss: 0.3704 - val_accuracy: 0.9000 - val_loss: 0.4767
# Epoch 109/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8621 - loss: 0.6858 - val_accuracy: 0.9000 - val_loss: 0.4979
# Epoch 110/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9482 - loss: 0.2350 - val_accuracy: 0.9500 - val_loss: 0.5018
# Epoch 111/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8868 - loss: 0.2811 - val_accuracy: 0.9500 - val_loss: 0.5000
# Epoch 112/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8310 - loss: 0.4675 - val_accuracy: 0.9500 - val_loss: 0.4473
# Epoch 113/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8848 - loss: 0.4701 - val_accuracy: 0.9000 - val_loss: 0.4289
# Epoch 114/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9157 - loss: 0.3647 - val_accuracy: 0.9500 - val_loss: 0.4343
# Epoch 115/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9383 - loss: 0.2600 - val_accuracy: 0.9500 - val_loss: 0.4496
# Epoch 116/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8522 - loss: 0.5269 - val_accuracy: 0.9500 - val_loss: 0.4569
# Epoch 117/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7936 - loss: 0.5715 - val_accuracy: 0.9500 - val_loss: 0.4553
# Epoch 118/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8469 - loss: 0.3925 - val_accuracy: 0.9500 - val_loss: 0.4491
# Epoch 119/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9234 - loss: 0.2233 - val_accuracy: 0.9500 - val_loss: 0.4461
# Epoch 120/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9355 - loss: 0.2811 - val_accuracy: 0.9500 - val_loss: 0.4599
# Epoch 121/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9343 - loss: 0.2536 - val_accuracy: 0.8500 - val_loss: 0.5082
# Epoch 122/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8638 - loss: 0.4094 - val_accuracy: 0.8500 - val_loss: 0.6684
# Epoch 123/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8490 - loss: 0.4827 - val_accuracy: 0.9000 - val_loss: 0.7089
# Epoch 124/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8369 - loss: 0.6365 - val_accuracy: 0.9000 - val_loss: 0.6258
# Epoch 125/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.3338 - val_accuracy: 0.9000 - val_loss: 0.5895
# Epoch 126/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8940 - loss: 0.4729 - val_accuracy: 0.9000 - val_loss: 0.5597
# Epoch 127/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8913 - loss: 0.3777 - val_accuracy: 0.9000 - val_loss: 0.5630
# Epoch 128/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9661 - loss: 0.2139 - val_accuracy: 0.9000 - val_loss: 0.5604
# Epoch 129/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8909 - loss: 0.4617 - val_accuracy: 0.9000 - val_loss: 0.5295
# Epoch 130/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8050 - loss: 0.4859 - val_accuracy: 0.9000 - val_loss: 0.4905
# Epoch 131/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8863 - loss: 0.4585 - val_accuracy: 0.9000 - val_loss: 0.6084
# Epoch 132/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8979 - loss: 0.6119 - val_accuracy: 0.8500 - val_loss: 0.2649
# Epoch 133/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8372 - loss: 0.5074 - val_accuracy: 0.8500 - val_loss: 0.2666
# Epoch 134/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8511 - loss: 0.4716 - val_accuracy: 0.8500 - val_loss: 0.2562
# Epoch 135/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7806 - loss: 1.2135 - val_accuracy: 0.9000 - val_loss: 0.2680
# Epoch 136/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8864 - loss: 0.3841 - val_accuracy: 0.9000 - val_loss: 0.2566
# Epoch 137/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9082 - loss: 0.3733 - val_accuracy: 0.9000 - val_loss: 0.2165
# Epoch 138/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8447 - loss: 0.8008 - val_accuracy: 0.9000 - val_loss: 0.1495
# Epoch 139/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8491 - loss: 0.4758 - val_accuracy: 0.9000 - val_loss: 0.2414
# Epoch 140/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8201 - loss: 0.5393 - val_accuracy: 0.9000 - val_loss: 0.3481
# Epoch 141/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8836 - loss: 0.4598 - val_accuracy: 0.9000 - val_loss: 0.3374
# Epoch 142/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7703 - loss: 0.7493 - val_accuracy: 0.9000 - val_loss: 0.2389
# Epoch 143/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6610 - loss: 0.8432 - val_accuracy: 0.9000 - val_loss: 0.2358
# Epoch 144/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8329 - loss: 0.5532 - val_accuracy: 0.9000 - val_loss: 0.2931
# Epoch 145/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8798 - loss: 0.7679 - val_accuracy: 0.9000 - val_loss: 0.3432
# Epoch 146/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8405 - loss: 0.5605 - val_accuracy: 0.9000 - val_loss: 0.3528
# Epoch 147/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7685 - loss: 1.1378 - val_accuracy: 0.9000 - val_loss: 0.2731
# Epoch 148/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8712 - loss: 0.5711 - val_accuracy: 0.9000 - val_loss: 0.2244
# Epoch 149/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9425 - loss: 0.2078 - val_accuracy: 0.9000 - val_loss: 0.2216
# Epoch 150/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8658 - loss: 0.5990 - val_accuracy: 0.8500 - val_loss: 0.2748
# Epoch 151/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8682 - loss: 0.3993 - val_accuracy: 0.8500 - val_loss: 0.3303
# Epoch 152/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8710 - loss: 0.3989 - val_accuracy: 0.8500 - val_loss: 0.3578
# Epoch 153/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8062 - loss: 1.4090 - val_accuracy: 0.8500 - val_loss: 0.4424
# Epoch 154/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6995 - loss: 0.9406 - val_accuracy: 0.8500 - val_loss: 0.3271
# Epoch 155/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9028 - loss: 0.3453 - val_accuracy: 0.9000 - val_loss: 0.2742
# Epoch 156/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.3447 - val_accuracy: 0.9500 - val_loss: 0.2685
# Epoch 157/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8204 - loss: 0.4994 - val_accuracy: 0.9000 - val_loss: 0.3004
# Epoch 158/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8373 - loss: 0.6361 - val_accuracy: 0.9000 - val_loss: 0.2758
# Epoch 159/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8426 - loss: 0.4872 - val_accuracy: 0.8500 - val_loss: 0.2762
# Epoch 160/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8897 - loss: 0.2863 - val_accuracy: 0.9000 - val_loss: 0.2817
# Epoch 161/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8395 - loss: 0.5315 - val_accuracy: 0.9000 - val_loss: 0.2918
# Epoch 162/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8450 - loss: 0.9436 - val_accuracy: 0.9000 - val_loss: 0.2485
# Epoch 163/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8422 - loss: 0.5253 - val_accuracy: 0.9000 - val_loss: 0.2512
# Epoch 164/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8257 - loss: 0.6075 - val_accuracy: 0.9000 - val_loss: 0.2646
# Epoch 165/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7435 - loss: 0.5994 - val_accuracy: 0.9000 - val_loss: 0.2624
# Epoch 166/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8213 - loss: 0.5312 - val_accuracy: 0.9000 - val_loss: 0.2807
# Epoch 167/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8988 - loss: 0.3959 - val_accuracy: 0.9000 - val_loss: 0.2901
# Epoch 168/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7812 - loss: 0.5430 - val_accuracy: 0.9000 - val_loss: 0.2691
# Epoch 169/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8624 - loss: 0.4118 - val_accuracy: 0.9000 - val_loss: 0.2646
# Epoch 170/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 0.6731 - val_accuracy: 0.9000 - val_loss: 0.2686
# Epoch 171/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8717 - loss: 0.5414 - val_accuracy: 0.9000 - val_loss: 0.2549
# Epoch 172/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8141 - loss: 0.6681 - val_accuracy: 0.9000 - val_loss: 0.2487
# Epoch 173/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8820 - loss: 0.3387 - val_accuracy: 0.9000 - val_loss: 0.2559
# Epoch 174/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9074 - loss: 0.2697 - val_accuracy: 0.9000 - val_loss: 0.2755
# Epoch 175/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9848 - loss: 0.1495 - val_accuracy: 0.9000 - val_loss: 0.2943
# Epoch 176/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8961 - loss: 0.3155 - val_accuracy: 0.9000 - val_loss: 0.2951
# Epoch 177/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8300 - loss: 0.4286 - val_accuracy: 0.9000 - val_loss: 0.2649
# Epoch 178/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.3037 - val_accuracy: 0.9000 - val_loss: 0.2445
# Epoch 179/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8500 - loss: 0.4900 - val_accuracy: 0.8500 - val_loss: 0.2535
# Epoch 180/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8795 - loss: 0.3566 - val_accuracy: 0.8500 - val_loss: 0.2635
# Epoch 181/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8970 - loss: 0.4150 - val_accuracy: 0.9000 - val_loss: 0.2551
# Epoch 182/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8339 - loss: 0.5694 - val_accuracy: 0.9000 - val_loss: 0.2397
# Epoch 183/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8524 - loss: 0.5088 - val_accuracy: 0.9000 - val_loss: 0.2877
# Epoch 184/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8154 - loss: 0.6445 - val_accuracy: 0.9000 - val_loss: 0.2952
# Epoch 185/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8445 - loss: 0.4947 - val_accuracy: 0.9000 - val_loss: 0.2979
# Epoch 186/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9304 - loss: 0.2840 - val_accuracy: 0.8500 - val_loss: 0.3109
# Epoch 187/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8713 - loss: 0.4763 - val_accuracy: 0.8500 - val_loss: 0.3106
# Epoch 188/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9238 - loss: 0.4064 - val_accuracy: 0.8500 - val_loss: 0.3341
# Epoch 189/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8798 - loss: 0.3530 - val_accuracy: 0.8500 - val_loss: 0.3324
# Epoch 190/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9557 - loss: 0.2030 - val_accuracy: 0.8500 - val_loss: 0.3416
# Epoch 191/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9116 - loss: 0.2828 - val_accuracy: 0.8500 - val_loss: 0.3665
# Epoch 192/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8503 - loss: 0.7091 - val_accuracy: 0.9000 - val_loss: 0.3638
# Epoch 193/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8226 - loss: 0.5318 - val_accuracy: 0.9000 - val_loss: 0.3252
# Epoch 194/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8542 - loss: 0.5900 - val_accuracy: 0.9000 - val_loss: 0.3106
# Epoch 195/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1686 - val_accuracy: 0.9000 - val_loss: 0.2884
# Epoch 196/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8238 - loss: 0.4387 - val_accuracy: 0.9000 - val_loss: 0.2771
# Epoch 197/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8074 - loss: 0.7058 - val_accuracy: 0.9000 - val_loss: 0.2785
# Epoch 198/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8187 - loss: 1.0111 - val_accuracy: 0.9000 - val_loss: 0.2880
# Epoch 199/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8901 - loss: 0.3261 - val_accuracy: 0.9500 - val_loss: 0.2971
# Epoch 200/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9608 - loss: 0.2741 - val_accuracy: 0.9500 - val_loss: 0.2959
# Epoch 201/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7637 - loss: 0.8099 - val_accuracy: 0.9500 - val_loss: 0.3191
# Epoch 202/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9528 - loss: 0.2699 - val_accuracy: 0.9500 - val_loss: 0.3355
# Epoch 203/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8073 - loss: 0.3652 - val_accuracy: 0.8500 - val_loss: 0.3356
# Epoch 204/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.2486 - val_accuracy: 0.9000 - val_loss: 0.3259
# Epoch 205/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7516 - loss: 0.4333 - val_accuracy: 0.9000 - val_loss: 0.3290
# Epoch 206/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9386 - loss: 0.2837 - val_accuracy: 0.8500 - val_loss: 0.3355
# Epoch 207/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8618 - loss: 0.4001 - val_accuracy: 0.8500 - val_loss: 0.3305
# Epoch 208/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8928 - loss: 0.3183 - val_accuracy: 0.9000 - val_loss: 0.3169
# Epoch 209/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8877 - loss: 0.4020 - val_accuracy: 0.9000 - val_loss: 0.3205
# Epoch 210/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8534 - loss: 0.4526 - val_accuracy: 0.8500 - val_loss: 0.3275
# Epoch 211/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8998 - loss: 0.4055 - val_accuracy: 0.8500 - val_loss: 0.3949
# Epoch 212/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.2644 - val_accuracy: 0.8500 - val_loss: 0.4660
# Epoch 213/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9437 - loss: 0.2206 - val_accuracy: 0.8500 - val_loss: 0.4884
# Epoch 214/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8683 - loss: 0.3792 - val_accuracy: 0.8500 - val_loss: 0.5104
# Epoch 215/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8983 - loss: 0.7291 - val_accuracy: 0.8500 - val_loss: 0.4807
# Epoch 216/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7425 - loss: 0.5665 - val_accuracy: 0.9000 - val_loss: 0.4163
# Epoch 217/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8805 - loss: 0.3629 - val_accuracy: 0.9500 - val_loss: 0.3720
# Epoch 218/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9156 - loss: 0.4554 - val_accuracy: 0.9500 - val_loss: 0.3636
# Epoch 219/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9527 - loss: 0.2038 - val_accuracy: 0.9500 - val_loss: 0.3737
# Epoch 220/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8431 - loss: 0.5279 - val_accuracy: 0.9500 - val_loss: 0.3703
# Epoch 221/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8480 - loss: 0.3942 - val_accuracy: 0.9500 - val_loss: 0.3660
# Epoch 222/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8518 - loss: 0.5304 - val_accuracy: 0.9000 - val_loss: 0.3643
# Epoch 223/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7794 - loss: 0.6733 - val_accuracy: 0.9000 - val_loss: 0.3440
# Epoch 224/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8988 - loss: 0.3680 - val_accuracy: 0.9000 - val_loss: 0.3348
# Epoch 225/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8681 - loss: 0.4992 - val_accuracy: 0.9500 - val_loss: 0.3227
# Epoch 226/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8751 - loss: 0.5451 - val_accuracy: 0.9500 - val_loss: 0.3153
# Epoch 227/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9123 - loss: 0.4488 - val_accuracy: 0.9500 - val_loss: 0.3336
# Epoch 228/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9068 - loss: 0.4374 - val_accuracy: 0.9500 - val_loss: 0.3351
# Epoch 229/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8456 - loss: 0.3474 - val_accuracy: 0.9500 - val_loss: 0.3392
# Epoch 230/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8779 - loss: 0.4832 - val_accuracy: 0.9500 - val_loss: 0.3503
# Epoch 231/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8986 - loss: 0.2469 - val_accuracy: 0.9500 - val_loss: 0.3553
# Epoch 232/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8660 - loss: 0.4684 - val_accuracy: 0.9500 - val_loss: 0.3702
# Epoch 233/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7988 - loss: 0.5752 - val_accuracy: 0.9500 - val_loss: 0.3926
# Epoch 234/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8765 - loss: 0.4953 - val_accuracy: 0.9000 - val_loss: 0.3891
# Epoch 235/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8968 - loss: 0.3220 - val_accuracy: 0.9000 - val_loss: 0.4392
# Epoch 236/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8453 - loss: 0.6165 - val_accuracy: 0.9000 - val_loss: 0.4204
# Epoch 237/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8673 - loss: 0.3005 - val_accuracy: 0.9000 - val_loss: 0.4166
# Epoch 238/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9212 - loss: 0.5109 - val_accuracy: 0.9000 - val_loss: 0.4178
# Epoch 239/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8198 - loss: 0.5564 - val_accuracy: 0.9000 - val_loss: 0.4131
# Epoch 240/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7747 - loss: 0.6120 - val_accuracy: 0.9000 - val_loss: 0.4399
# Epoch 241/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8916 - loss: 0.3087 - val_accuracy: 0.9500 - val_loss: 0.4501
# Epoch 242/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8782 - loss: 0.4473 - val_accuracy: 0.9500 - val_loss: 0.4137
# Epoch 243/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8893 - loss: 0.3802 - val_accuracy: 0.9000 - val_loss: 0.4173
# Epoch 244/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8557 - loss: 0.4666 - val_accuracy: 0.9000 - val_loss: 0.5085
# Epoch 245/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7893 - loss: 0.6954 - val_accuracy: 0.9000 - val_loss: 0.5423
# Epoch 246/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8698 - loss: 0.4933 - val_accuracy: 0.9000 - val_loss: 0.5928
# Epoch 247/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8163 - loss: 0.6715 - val_accuracy: 0.9000 - val_loss: 0.6424
# Epoch 248/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9042 - loss: 0.2328 - val_accuracy: 0.9000 - val_loss: 0.6808
# Epoch 249/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8169 - loss: 0.5365 - val_accuracy: 0.9000 - val_loss: 0.7122
# Epoch 250/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9696 - loss: 0.1998 - val_accuracy: 0.9000 - val_loss: 0.7222
# Epoch 251/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8681 - loss: 0.5405 - val_accuracy: 0.9000 - val_loss: 0.7181
# Epoch 252/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8171 - loss: 0.6813 - val_accuracy: 0.9000 - val_loss: 0.7269
# Epoch 253/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.1595 - val_accuracy: 0.9000 - val_loss: 0.7247
# Epoch 254/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7903 - loss: 0.6198 - val_accuracy: 0.9000 - val_loss: 0.7226
# Epoch 255/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8605 - loss: 0.3222 - val_accuracy: 0.9000 - val_loss: 0.7045
# Epoch 256/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8999 - loss: 0.3619 - val_accuracy: 0.9000 - val_loss: 0.7151
# Epoch 257/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8802 - loss: 0.6074 - val_accuracy: 0.9000 - val_loss: 0.7113
# Epoch 258/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8597 - loss: 0.4010 - val_accuracy: 0.9000 - val_loss: 0.6594
# Epoch 259/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9499 - loss: 0.2184 - val_accuracy: 0.9000 - val_loss: 0.6726
# Epoch 260/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7865 - loss: 0.4736 - val_accuracy: 0.9000 - val_loss: 0.6852
# Epoch 261/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9045 - loss: 0.3534 - val_accuracy: 0.9000 - val_loss: 0.6559
# Epoch 262/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8831 - loss: 0.1845 - val_accuracy: 0.9000 - val_loss: 0.6560
# Epoch 263/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8991 - loss: 0.4002 - val_accuracy: 0.8500 - val_loss: 0.7156
# Epoch 264/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8380 - loss: 0.3603 - val_accuracy: 0.8500 - val_loss: 0.7255
# Epoch 265/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9021 - loss: 0.2667 - val_accuracy: 0.8500 - val_loss: 0.6613
# Epoch 266/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7800 - loss: 1.0419 - val_accuracy: 0.8500 - val_loss: 0.6645
# Epoch 267/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7197 - loss: 0.9433 - val_accuracy: 0.8500 - val_loss: 0.7319
# Epoch 268/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8752 - loss: 0.3634 - val_accuracy: 0.8500 - val_loss: 0.5896
# Epoch 269/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9462 - loss: 0.2879 - val_accuracy: 0.8500 - val_loss: 0.5553
# Epoch 270/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.2467 - val_accuracy: 0.8500 - val_loss: 0.5935
# Epoch 271/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8954 - loss: 0.3191 - val_accuracy: 0.8500 - val_loss: 0.6256
# Epoch 272/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7228 - loss: 1.0503 - val_accuracy: 0.8500 - val_loss: 0.6267
# Epoch 273/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7528 - loss: 0.7647 - val_accuracy: 0.8500 - val_loss: 0.6415
# Epoch 274/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8795 - loss: 0.3205 - val_accuracy: 0.9000 - val_loss: 0.5291
# Epoch 275/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.4585 - val_accuracy: 0.9000 - val_loss: 0.4089
# Epoch 276/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7728 - loss: 0.4547 - val_accuracy: 0.9000 - val_loss: 0.3866
# Epoch 277/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8988 - loss: 0.5113 - val_accuracy: 0.9000 - val_loss: 0.3867
# Epoch 278/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9470 - loss: 0.2160 - val_accuracy: 0.9000 - val_loss: 0.3806
# Epoch 279/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8565 - loss: 0.4938 - val_accuracy: 0.9000 - val_loss: 0.3351
# Epoch 280/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8545 - loss: 0.4057 - val_accuracy: 0.9000 - val_loss: 0.3307
# Epoch 281/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8209 - loss: 0.6660 - val_accuracy: 0.9000 - val_loss: 0.3315
# Epoch 282/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7952 - loss: 0.5256 - val_accuracy: 0.9000 - val_loss: 0.3102
# Epoch 283/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9366 - loss: 0.3633 - val_accuracy: 0.9500 - val_loss: 0.2434
# Epoch 284/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8834 - loss: 0.6448 - val_accuracy: 0.9500 - val_loss: 0.2328
# Epoch 285/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8177 - loss: 0.5201 - val_accuracy: 0.9500 - val_loss: 0.2364
# Epoch 286/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8691 - loss: 0.4565 - val_accuracy: 0.9500 - val_loss: 0.2217
# Epoch 287/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9136 - loss: 0.3259 - val_accuracy: 0.9500 - val_loss: 0.2013
# Epoch 288/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8705 - loss: 0.5401 - val_accuracy: 0.9500 - val_loss: 0.1991
# Epoch 289/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8020 - loss: 0.5026 - val_accuracy: 0.9500 - val_loss: 0.1910
# Epoch 290/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8235 - loss: 0.4590 - val_accuracy: 0.9500 - val_loss: 0.1947
# Epoch 291/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7538 - loss: 0.4912 - val_accuracy: 0.9000 - val_loss: 0.2316
# Epoch 292/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7268 - loss: 0.5496 - val_accuracy: 0.9000 - val_loss: 0.3973
# Epoch 293/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8707 - loss: 0.3982 - val_accuracy: 0.9000 - val_loss: 0.3021
# Epoch 294/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8357 - loss: 0.3962 - val_accuracy: 0.9000 - val_loss: 0.2980
# Epoch 295/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8325 - loss: 0.4995 - val_accuracy: 0.9000 - val_loss: 0.3063
# Epoch 296/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8629 - loss: 0.5112 - val_accuracy: 0.9000 - val_loss: 0.3472
# Epoch 297/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8089 - loss: 0.5484 - val_accuracy: 0.9000 - val_loss: 0.3931
# Epoch 298/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8889 - loss: 0.4579 - val_accuracy: 0.9000 - val_loss: 0.4743
# Epoch 299/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7426 - loss: 0.7765 - val_accuracy: 0.9000 - val_loss: 0.4418
# Epoch 300/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8875 - loss: 0.3541 - val_accuracy: 0.9000 - val_loss: 0.3890
# Epoch 301/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9287 - loss: 0.3541 - val_accuracy: 0.9000 - val_loss: 0.4030
# Epoch 302/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8909 - loss: 0.3564 - val_accuracy: 0.9000 - val_loss: 0.4586
# Epoch 303/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6946 - loss: 1.0511 - val_accuracy: 0.9500 - val_loss: 0.3868
# Epoch 304/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8673 - loss: 0.3452 - val_accuracy: 0.9500 - val_loss: 0.3851
# Epoch 305/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8939 - loss: 0.3141 - val_accuracy: 0.9500 - val_loss: 0.3822
# Epoch 306/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8682 - loss: 0.4761 - val_accuracy: 0.9500 - val_loss: 0.3932
# Epoch 307/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8773 - loss: 0.4231 - val_accuracy: 0.9500 - val_loss: 0.4040
# Epoch 308/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8336 - loss: 0.5228 - val_accuracy: 0.9500 - val_loss: 0.2936
# Epoch 309/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7985 - loss: 0.6780 - val_accuracy: 0.9500 - val_loss: 0.2142
# Epoch 310/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8473 - loss: 0.4470 - val_accuracy: 0.9500 - val_loss: 0.1921
# Epoch 311/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9030 - loss: 0.2593 - val_accuracy: 0.9500 - val_loss: 0.2052
# Epoch 312/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8838 - loss: 0.3877 - val_accuracy: 0.9500 - val_loss: 0.2175
# Epoch 313/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8965 - loss: 0.3813 - val_accuracy: 0.9500 - val_loss: 0.2381
# Epoch 314/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.6802 - val_accuracy: 0.9500 - val_loss: 0.2620
# Epoch 315/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8491 - loss: 0.3860 - val_accuracy: 0.9500 - val_loss: 0.2886
# Epoch 316/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8798 - loss: 0.4662 - val_accuracy: 0.9500 - val_loss: 0.2755
# Epoch 317/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8715 - loss: 0.7481 - val_accuracy: 0.9500 - val_loss: 0.3096
# Epoch 318/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9015 - loss: 0.3504 - val_accuracy: 0.9500 - val_loss: 0.3140
# Epoch 319/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9485 - loss: 0.1910 - val_accuracy: 0.9500 - val_loss: 0.2583
# Epoch 320/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8039 - loss: 0.7284 - val_accuracy: 0.9500 - val_loss: 0.1409
# Epoch 321/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7626 - loss: 1.2141 - val_accuracy: 0.9500 - val_loss: 0.1572
# Epoch 322/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9060 - loss: 0.3663 - val_accuracy: 0.9500 - val_loss: 0.1528
# Epoch 323/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8514 - loss: 0.4579 - val_accuracy: 0.9500 - val_loss: 0.1505
# Epoch 324/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8311 - loss: 0.5222 - val_accuracy: 0.9500 - val_loss: 0.1586
# Epoch 325/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9267 - loss: 0.7000 - val_accuracy: 0.9500 - val_loss: 0.1644
# Epoch 326/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8482 - loss: 0.4156 - val_accuracy: 0.9500 - val_loss: 0.1795
# Epoch 327/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8758 - loss: 0.4299 - val_accuracy: 0.9500 - val_loss: 0.1918
# Epoch 328/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9519 - loss: 0.2765 - val_accuracy: 0.9500 - val_loss: 0.2197
# Epoch 329/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8807 - loss: 0.4558 - val_accuracy: 0.9500 - val_loss: 0.2645
# Epoch 330/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8009 - loss: 0.4607 - val_accuracy: 0.9500 - val_loss: 0.2819
# Epoch 331/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7983 - loss: 0.6510 - val_accuracy: 0.9500 - val_loss: 0.2935
# Epoch 332/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7787 - loss: 0.7479 - val_accuracy: 0.9500 - val_loss: 0.2736
# Epoch 333/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9290 - loss: 0.2220 - val_accuracy: 0.9500 - val_loss: 0.2508
# Epoch 334/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8060 - loss: 0.6588 - val_accuracy: 0.9500 - val_loss: 0.2414
# Epoch 335/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8785 - loss: 0.3466 - val_accuracy: 0.9500 - val_loss: 0.2385
# Epoch 336/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8241 - loss: 0.4879 - val_accuracy: 0.9500 - val_loss: 0.2483
# Epoch 337/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7332 - loss: 0.8567 - val_accuracy: 0.9500 - val_loss: 0.2832
# Epoch 338/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8923 - loss: 0.2961 - val_accuracy: 0.9500 - val_loss: 0.2921
# Epoch 339/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8619 - loss: 0.3136 - val_accuracy: 0.9500 - val_loss: 0.2605
# Epoch 340/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8746 - loss: 0.3428 - val_accuracy: 0.9500 - val_loss: 0.2637
# Epoch 341/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8366 - loss: 0.5808 - val_accuracy: 0.9500 - val_loss: 0.2625
# Epoch 342/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9242 - loss: 0.2823 - val_accuracy: 0.9500 - val_loss: 0.2887
# Epoch 343/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8565 - loss: 0.4249 - val_accuracy: 0.9500 - val_loss: 0.2983
# Epoch 344/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7780 - loss: 1.2824 - val_accuracy: 0.9500 - val_loss: 0.2082
# Epoch 345/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9035 - loss: 0.2349 - val_accuracy: 0.9500 - val_loss: 0.2976
# Epoch 346/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7374 - loss: 0.9323 - val_accuracy: 0.9500 - val_loss: 0.3157
# Epoch 347/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8296 - loss: 0.4518 - val_accuracy: 0.9500 - val_loss: 0.3292
# Epoch 348/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8613 - loss: 0.4409 - val_accuracy: 0.9500 - val_loss: 0.3492
# Epoch 349/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9114 - loss: 0.3628 - val_accuracy: 0.9500 - val_loss: 0.3166
# Epoch 350/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9069 - loss: 0.3816 - val_accuracy: 0.9500 - val_loss: 0.2968
# Epoch 351/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8536 - loss: 0.3840 - val_accuracy: 0.9500 - val_loss: 0.2933
# Epoch 352/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8129 - loss: 0.4976 - val_accuracy: 0.9500 - val_loss: 0.3086
# Epoch 353/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7826 - loss: 0.7091 - val_accuracy: 0.9500 - val_loss: 0.3406
# Epoch 354/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9199 - loss: 0.4192 - val_accuracy: 0.9500 - val_loss: 0.3519
# Epoch 355/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7602 - loss: 0.6497 - val_accuracy: 0.9000 - val_loss: 0.3772
# Epoch 356/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.3574 - val_accuracy: 0.9500 - val_loss: 0.3240
# Epoch 357/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8332 - loss: 0.4106 - val_accuracy: 0.9500 - val_loss: 0.3158
# Epoch 358/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8528 - loss: 0.4355 - val_accuracy: 0.9500 - val_loss: 0.2829
# Epoch 359/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7892 - loss: 0.6041 - val_accuracy: 0.9500 - val_loss: 0.3919
# Epoch 360/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8691 - loss: 0.3747 - val_accuracy: 0.9500 - val_loss: 0.4440
# Epoch 361/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7974 - loss: 0.6865 - val_accuracy: 0.9500 - val_loss: 0.4898
# Epoch 362/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8535 - loss: 0.7373 - val_accuracy: 0.9500 - val_loss: 0.3999
# Epoch 363/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8156 - loss: 0.9337 - val_accuracy: 0.9500 - val_loss: 0.3671
# Epoch 364/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8214 - loss: 0.5094 - val_accuracy: 0.9500 - val_loss: 0.3745
# Epoch 365/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8217 - loss: 0.5056 - val_accuracy: 0.9500 - val_loss: 0.3846
# Epoch 366/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9288 - loss: 0.3562 - val_accuracy: 0.9500 - val_loss: 0.2680
# Epoch 367/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7963 - loss: 0.5398 - val_accuracy: 0.9500 - val_loss: 0.1735
# Epoch 368/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9285 - loss: 0.3391 - val_accuracy: 0.9500 - val_loss: 0.1698
# Epoch 369/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7159 - loss: 0.8856 - val_accuracy: 0.9500 - val_loss: 0.2480
# Epoch 370/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9158 - loss: 0.1929 - val_accuracy: 0.9500 - val_loss: 0.2362
# ...
# Epoch 878/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8162 - loss: 0.4186 - val_accuracy: 0.9500 - val_loss: 0.4483
# Epoch 879/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9053 - loss: 0.3470 - val_accuracy: 0.9500 - val_loss: 0.4902
# Epoch 880/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8037 - loss: 0.6555 - val_accuracy: 0.9500 - val_loss: 0.5046
# Epoch 881/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8949 - loss: 0.4023 - val_accuracy: 0.9500 - val_loss: 0.5210
# Epoch 882/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9452 - loss: 0.2423 - val_accuracy: 0.9500 - val_loss: 0.5244
# Epoch 883/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.5386 - val_accuracy: 0.9500 - val_loss: 0.5247
# Epoch 884/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8885 - loss: 0.6036 - val_accuracy: 0.9500 - val_loss: 0.5214
# Epoch 885/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.4465 - val_accuracy: 0.9500 - val_loss: 0.5240
# Epoch 886/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7907 - loss: 0.6013 - val_accuracy: 0.9500 - val_loss: 0.5242
# Epoch 887/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8783 - loss: 0.3609 - val_accuracy: 0.9500 - val_loss: 0.5338
# Epoch 888/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8421 - loss: 0.4851 - val_accuracy: 0.9500 - val_loss: 0.4961
# Epoch 889/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7822 - loss: 0.5172 - val_accuracy: 0.9500 - val_loss: 0.5000
# Epoch 890/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8808 - loss: 0.4053 - val_accuracy: 0.9500 - val_loss: 0.4843
# Epoch 891/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8200 - loss: 0.4622 - val_accuracy: 0.9500 - val_loss: 0.4609
# Epoch 892/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8963 - loss: 0.4930 - val_accuracy: 0.9500 - val_loss: 0.4452
# Epoch 893/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8097 - loss: 0.6831 - val_accuracy: 0.9500 - val_loss: 0.4960
# Epoch 894/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8109 - loss: 0.9806 - val_accuracy: 0.9500 - val_loss: 0.4633
# Epoch 895/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8099 - loss: 0.5526 - val_accuracy: 0.9500 - val_loss: 0.4454
# Epoch 896/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8729 - loss: 0.4110 - val_accuracy: 0.9500 - val_loss: 0.4435
# Epoch 897/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8900 - loss: 0.3345 - val_accuracy: 0.9500 - val_loss: 0.4799
# Epoch 898/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9231 - loss: 0.3137 - val_accuracy: 0.9500 - val_loss: 0.4404
# Epoch 899/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8591 - loss: 0.3463 - val_accuracy: 0.9500 - val_loss: 0.4380
# Epoch 900/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8939 - loss: 0.3382 - val_accuracy: 0.9500 - val_loss: 0.4367
# Epoch 901/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8446 - loss: 0.4595 - val_accuracy: 0.9500 - val_loss: 0.4351
# Epoch 902/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7937 - loss: 0.6666 - val_accuracy: 0.9500 - val_loss: 0.4358
# Epoch 903/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8417 - loss: 0.6818 - val_accuracy: 0.9500 - val_loss: 0.4399
# Epoch 904/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8808 - loss: 0.4839 - val_accuracy: 0.9500 - val_loss: 0.4385
# Epoch 905/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6808 - loss: 1.7748 - val_accuracy: 0.9500 - val_loss: 0.4700
# Epoch 906/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8951 - loss: 0.3319 - val_accuracy: 0.9500 - val_loss: 0.4819
# Epoch 907/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8728 - loss: 0.4586 - val_accuracy: 0.9500 - val_loss: 0.4527
# Epoch 908/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9481 - loss: 0.2491 - val_accuracy: 0.9500 - val_loss: 0.4755
# Epoch 909/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8167 - loss: 0.6299 - val_accuracy: 0.9500 - val_loss: 0.4793
# Epoch 910/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7379 - loss: 0.8844 - val_accuracy: 0.9500 - val_loss: 0.4359
# Epoch 911/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8789 - loss: 0.3834 - val_accuracy: 0.9500 - val_loss: 0.4067
# Epoch 912/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9105 - loss: 0.3833 - val_accuracy: 0.9500 - val_loss: 0.3884
# Epoch 913/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9000 - loss: 0.3557 - val_accuracy: 0.9500 - val_loss: 0.3222
# Epoch 914/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8690 - loss: 0.3752 - val_accuracy: 0.9500 - val_loss: 0.3187
# Epoch 915/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9077 - loss: 0.3583 - val_accuracy: 0.9500 - val_loss: 0.3236
# Epoch 916/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8001 - loss: 0.7397 - val_accuracy: 0.9500 - val_loss: 0.3070
# Epoch 917/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8458 - loss: 0.5142 - val_accuracy: 0.9500 - val_loss: 0.3400
# Epoch 918/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8291 - loss: 0.5512 - val_accuracy: 0.9500 - val_loss: 0.3439
# Epoch 919/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8682 - loss: 0.5520 - val_accuracy: 0.9500 - val_loss: 0.3150
# Epoch 920/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9490 - loss: 0.2958 - val_accuracy: 0.9500 - val_loss: 0.3049
# Epoch 921/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8565 - loss: 0.4850 - val_accuracy: 0.9500 - val_loss: 0.3058
# Epoch 922/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8325 - loss: 0.6276 - val_accuracy: 0.9500 - val_loss: 0.2752
# Epoch 923/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8895 - loss: 0.3167 - val_accuracy: 0.9500 - val_loss: 0.2703
# Epoch 924/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8655 - loss: 0.4193 - val_accuracy: 0.9500 - val_loss: 0.3163
# Epoch 925/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9326 - loss: 0.2090 - val_accuracy: 0.9500 - val_loss: 0.2702
# Epoch 926/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8148 - loss: 0.6152 - val_accuracy: 0.9500 - val_loss: 0.2615
# Epoch 927/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9286 - loss: 0.2099 - val_accuracy: 0.9500 - val_loss: 0.3502
# Epoch 928/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7581 - loss: 0.6265 - val_accuracy: 0.9500 - val_loss: 0.3795
# Epoch 929/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8557 - loss: 0.6027 - val_accuracy: 0.9500 - val_loss: 0.4076
# Epoch 930/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8688 - loss: 0.4993 - val_accuracy: 0.9500 - val_loss: 0.4100
# Epoch 931/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9756 - loss: 0.1688 - val_accuracy: 0.9500 - val_loss: 0.4041
# Epoch 932/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9083 - loss: 0.1491 - val_accuracy: 0.9500 - val_loss: 0.4049
# Epoch 933/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8463 - loss: 0.3898 - val_accuracy: 0.9500 - val_loss: 0.3790
# Epoch 934/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9024 - loss: 0.2468 - val_accuracy: 0.9500 - val_loss: 0.3603
# Epoch 935/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9361 - loss: 0.2665 - val_accuracy: 0.9500 - val_loss: 0.3458
# Epoch 936/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8936 - loss: 0.3588 - val_accuracy: 0.9500 - val_loss: 0.3361
# Epoch 937/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8638 - loss: 0.2135 - val_accuracy: 0.9500 - val_loss: 0.3022
# Epoch 938/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8848 - loss: 0.2683 - val_accuracy: 0.9500 - val_loss: 0.2528
# Epoch 939/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9468 - loss: 0.2856 - val_accuracy: 0.9500 - val_loss: 0.3020
# Epoch 940/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8809 - loss: 0.4986 - val_accuracy: 0.9500 - val_loss: 0.3286
# Epoch 941/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8589 - loss: 0.4342 - val_accuracy: 0.9500 - val_loss: 0.3694
# Epoch 942/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9241 - loss: 0.2130 - val_accuracy: 0.9500 - val_loss: 0.4013
# Epoch 943/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8642 - loss: 0.4130 - val_accuracy: 0.9500 - val_loss: 0.4102
# Epoch 944/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9304 - loss: 0.4046 - val_accuracy: 0.9500 - val_loss: 0.4085
# Epoch 945/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9834 - loss: 0.1433 - val_accuracy: 0.9500 - val_loss: 0.4174
# Epoch 946/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8640 - loss: 0.3066 - val_accuracy: 0.9500 - val_loss: 0.3869
# Epoch 947/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8173 - loss: 0.5704 - val_accuracy: 0.9500 - val_loss: 0.3629
# Epoch 948/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9434 - loss: 0.1853 - val_accuracy: 0.9500 - val_loss: 0.3728
# Epoch 949/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9338 - loss: 0.2207 - val_accuracy: 0.9500 - val_loss: 0.3588
# Epoch 950/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9462 - loss: 0.3340 - val_accuracy: 0.9500 - val_loss: 0.3480
# Epoch 951/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8816 - loss: 0.2594 - val_accuracy: 0.9500 - val_loss: 0.3580
# Epoch 952/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9091 - loss: 0.3115 - val_accuracy: 0.9500 - val_loss: 0.3808
# Epoch 953/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8417 - loss: 0.4659 - val_accuracy: 0.9500 - val_loss: 0.3602
# Epoch 954/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8530 - loss: 0.3771 - val_accuracy: 0.9500 - val_loss: 0.3479
# Epoch 955/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7577 - loss: 0.5789 - val_accuracy: 0.9500 - val_loss: 0.3568
# Epoch 956/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8963 - loss: 0.3219 - val_accuracy: 0.9500 - val_loss: 0.3840
# Epoch 957/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8557 - loss: 0.5806 - val_accuracy: 0.9500 - val_loss: 0.3891
# Epoch 958/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8483 - loss: 0.3146 - val_accuracy: 0.9500 - val_loss: 0.4110
# Epoch 959/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9161 - loss: 0.6168 - val_accuracy: 0.9500 - val_loss: 0.1506
# Epoch 960/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8212 - loss: 0.5984 - val_accuracy: 0.9500 - val_loss: 0.1168
# Epoch 961/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7667 - loss: 0.7801 - val_accuracy: 0.9500 - val_loss: 0.1050
# Epoch 962/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9281 - loss: 0.4154 - val_accuracy: 1.0000 - val_loss: 0.0790
# Epoch 963/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8490 - loss: 0.4719 - val_accuracy: 1.0000 - val_loss: 0.0703
# Epoch 964/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8432 - loss: 0.5123 - val_accuracy: 0.9500 - val_loss: 0.0925
# Epoch 965/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7587 - loss: 0.6653 - val_accuracy: 0.9500 - val_loss: 0.1655
# Epoch 966/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8871 - loss: 0.3250 - val_accuracy: 0.9500 - val_loss: 0.1933
# Epoch 967/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8411 - loss: 0.4433 - val_accuracy: 0.9500 - val_loss: 0.1593
# Epoch 968/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8788 - loss: 0.6178 - val_accuracy: 0.9500 - val_loss: 0.2833
# Epoch 969/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6478 - loss: 0.9814 - val_accuracy: 0.9500 - val_loss: 0.3355
# Epoch 970/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7367 - loss: 0.7889 - val_accuracy: 0.9500 - val_loss: 0.2084
# Epoch 971/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8686 - loss: 0.4284 - val_accuracy: 0.9500 - val_loss: 0.2005
# Epoch 972/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8385 - loss: 0.4313 - val_accuracy: 0.9500 - val_loss: 0.2121
# Epoch 973/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9164 - loss: 0.2822 - val_accuracy: 0.9500 - val_loss: 0.3328
# Epoch 974/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8654 - loss: 0.5318 - val_accuracy: 0.9500 - val_loss: 0.3220
# Epoch 975/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8604 - loss: 0.5308 - val_accuracy: 0.9500 - val_loss: 0.3245
# Epoch 976/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8181 - loss: 0.5548 - val_accuracy: 0.9500 - val_loss: 0.3296
# Epoch 977/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9056 - loss: 0.4477 - val_accuracy: 0.9500 - val_loss: 0.3302
# Epoch 978/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9198 - loss: 0.3691 - val_accuracy: 0.9500 - val_loss: 0.3306
# Epoch 979/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8780 - loss: 0.3138 - val_accuracy: 0.9500 - val_loss: 0.3416
# Epoch 980/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7872 - loss: 0.6500 - val_accuracy: 0.9500 - val_loss: 0.3522
# Epoch 981/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.4849 - val_accuracy: 0.9500 - val_loss: 0.3676
# Epoch 982/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8282 - loss: 0.6648 - val_accuracy: 0.9500 - val_loss: 0.3763
# Epoch 983/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8152 - loss: 0.5487 - val_accuracy: 0.9500 - val_loss: 0.3692
# Epoch 984/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7632 - loss: 0.5753 - val_accuracy: 0.9500 - val_loss: 0.3657
# Epoch 985/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8153 - loss: 0.7392 - val_accuracy: 0.9500 - val_loss: 0.3630
# Epoch 986/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9014 - loss: 0.2274 - val_accuracy: 0.9500 - val_loss: 0.3634
# Epoch 987/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8529 - loss: 0.3365 - val_accuracy: 0.9500 - val_loss: 0.3578
# Epoch 988/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8124 - loss: 0.5606 - val_accuracy: 0.9500 - val_loss: 0.3731
# Epoch 989/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8708 - loss: 0.8995 - val_accuracy: 0.9500 - val_loss: 0.4249
# Epoch 990/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8201 - loss: 0.4600 - val_accuracy: 0.9500 - val_loss: 0.4676
# Epoch 991/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8184 - loss: 0.6303 - val_accuracy: 0.9500 - val_loss: 0.4531
# Epoch 992/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8076 - loss: 0.6176 - val_accuracy: 0.9500 - val_loss: 0.4159
# Epoch 993/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7870 - loss: 0.5204 - val_accuracy: 0.9500 - val_loss: 0.3921
# Epoch 994/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8282 - loss: 0.4807 - val_accuracy: 0.9500 - val_loss: 0.3722
# Epoch 995/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8338 - loss: 0.4938 - val_accuracy: 0.9500 - val_loss: 0.2857
# Epoch 996/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9177 - loss: 0.2866 - val_accuracy: 0.9500 - val_loss: 0.2523
# Epoch 997/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8886 - loss: 0.6346 - val_accuracy: 0.9500 - val_loss: 0.2791
# Epoch 998/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8229 - loss: 0.4617 - val_accuracy: 0.9500 - val_loss: 0.2711
# Epoch 999/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8767 - loss: 0.3626 - val_accuracy: 0.9500 - val_loss: 0.2734
# Epoch 1000/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8986 - loss: 0.2957 - val_accuracy: 0.9500 - val_loss: 0.2838

# %%
validation_test_set_accuracy = model.evaluate(xtest, ytest, verbose=0)
print(validation_test_set_accuracy[1])
# Out:
# 0.949999988079071

# %%
y_pred = np.argmax(model.predict(xtest), axis=1)
y_true = np.argmax(ytest, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
cm = confusion_matrix(y_true, y_pred, labels=np.arange(num_classes))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labelencoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.xticks(rotation=90)
plt.show()

# %%
precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
print("Precision:",precision)
# Out:
# Precision: 0.925

# %%
recall = recall_score(y_true, y_pred, average='macro', zero_division=0)
print("Recall(Sensitivity):",recall)
# Out:
# Recall(Sensitivity): 0.95

# %%
y_prob = model.predict(xtest)
auc_roc = roc_auc_score(ytest, y_prob, average='macro', multi_class='ovr')
print("AUC-ROC:",auc_roc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# AUC-ROC: 0.9947368421052631

# %%
result_bugs = labelencoder.classes_

# %%
recorded_audio, recorded_sample_rate = record_audio(duration=6)
# Out:
# Recording...
# Recording complete.

# %%
classification_result = classify_sound(recorded_audio)
print("Classification Result:", classification_result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Classification Result: Dor Beetle

# %%
mfcc_features_recorded = feature_extractor(recorded_audio, recorded_sample_rate)
mfccs_scaled_features_recorded = mfcc_features_recorded.reshape(1, -1)

# %%
result_array_recorded = model.predict(mfccs_scaled_features_recorded)
result_recorded = np.argmax(result_array_recorded[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
model_save_path = os.path.join(base_dir, "App/models/model.h5")
labelencoder_save_path = os.path.join(base_dir, "App/models/labelencoder.npy")

# %%
model.save(model_save_path)
np.save(labelencoder_save_path, labelencoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from IPython.display import Audio

if classification_result == "Non-bug Sound":
    print("Non-bug Sound")

elif result_bugs[result_recorded]=="Bee":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Bee.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Bees are flying insects closely related to wasps and ants.\n")
    print("Role: Crucial pollinators for many plants and crops.\n")
    print("Honey Production: Honeybees produce honey from nectar.\n")
    print("Social Structure: Many bees live in colonies with a queen, workers, and drones..\n")
    print("Communication: Honeybees use the waggle dance to share information.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/bee.wav")))

elif result_bugs[result_recorded]=="Beetle":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Beetle.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Beetles are insects with hard exoskeletons and forewings called elytra, known for their immense diversity and roles as decomposers, pollinators, and predators.\n")
    print("Role: Key decomposers and pollinators, essential for ecosystems.\n")
    print("Diet: Includes plants, other insects, and decomposing matter.\n")
    print("Habitat: Found almost everywhere.\n")
    print("Diversity: Includes well-known types like ladybugs, fireflies, and dung beetles.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/beetle.wav")))

elif result_bugs[result_recorded]=="Bess Beetle":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Bess Beetle.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Bess beetles are a type of beetle known for their hard bodies and social behavior.\n")
    print("Role: Important decomposers, breaking down wood and recycling nutrients in forest ecosystems.\n")
    print("Traits: Hard exoskeleton and strong mandibles for chewing wood.\n")
    print("Habitat: Found in decaying wood, particularly in forests.\n")
    print("Diet: Feeds on decaying wood and fungi within it.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/bessbeetle.wav")))

elif result_bugs[result_recorded]=="Bumblebee":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Bumblebee.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Bumblebees are robust flying insects closely related to honeybees.\n")
    print("Role:Bumblebees play a crucial role in ecosystems and agriculture by pollinating plants and contributing to biodiversity, making their conservation essential for sustainable food production and natural habitats.\n")
    print("Characteristics: Bumblebees are large, fuzzy insects with round bodies covered in soft hair.\n")
    print("Behavior: Bumblebees are social insects that live in colonies with a queen, workers, and drones.\n")
    print("Habitat: They are found primarily in temperate climates, but some species can also be found in higher altitudes or in tropical regions.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/bumblebee.wav")))
    
elif result_bugs[result_recorded]=="Butterfly":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Butterfly.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Butterflies are colorful flying insects known for their delicate wings and important role in pollination.\n")
    print("Role: Important pollinators contributing to ecosystem health and biodiversity.\n")
    print("Species: Belong to the order Lepidoptera, with numerous species worldwide.\n")
    print("Habitat: Found in diverse habitats, including gardens, meadows, and forests.\n")
    print("Traits: Delicate wings covered in scales, colorful patterns for camouflage and signaling.\n")
    print("Diet: Adults feed on flower nectar; caterpillars feed on host plants.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/butterfly.wav")))

elif result_bugs[result_recorded]=="Click Beetle":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Click Beetle.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Click beetles, scientifically known as Elateridae, are a family of beetles characterized by their ability to flip themselves into the air with an audible clicking sound when placed on their backs.\n")
    print("Role: Click beetles are important decomposers in ecosystems, helping to break down organic matter and recycle nutrients.\n")
    print("Traits: They are characterized by a unique mechanism that allows them to click and flip into the air when placed on their backs, aiding in escaping predators.\n")
    print("Habitat: Click beetles are found in diverse habitats including forests, fields, and gardens.\n")
    print("Diet: As larvae, they feed on decaying plant material and roots. Adults primarily feed on nectar and pollen.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/clickbeetle.wav")))
    
elif result_bugs[result_recorded]=="Cockroach":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Cockroach.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Cockroaches are known for their resilience and adaptability, thriving in various environments worldwide.\n")
    print("Role: Cockroaches play a role in ecosystems as decomposers, breaking down organic matter. However, they are often considered pests due to their presence in human habitats, where they can spread diseases and trigger.\n")
    print("Habitat: Found in various environments, particularly warm and humid areas such as kitchens, bathrooms, and basements.\n")
    print("Diet: Omnivorous scavengers that feed on organic matter, including food scraps, decaying material, and even glue and paper.\n")
    print("Traits: They are characterized by their flattened bodies, long antennae, and a pair of wings that may be either fully developed or reduced.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/cockroach.wav")))

elif result_bugs[result_recorded]=="Cricket":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Cricket.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Crickets are insects belonging to the family Gryllidae, known for their distinctive chirping sounds, which males produce by rubbing their wings together to attract females. \n")
    print("Role: Crickets are important for nutrient cycling, soil health, and serve as prey for many predators.\n")
    print("Habitat: Found in various habitats including fields, forests, gardens, and sometimes inside buildings.\n")
    print("Traits: Crickets have cylindrical bodies, long antennae.\n")
    print("Diet: Omnivorous, feeding on plants, fungi, and small insects.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/cricket.wav")))

elif result_bugs[result_recorded]=="Dor Beetle":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Dor Beetle.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Dor beetles dig tunnels beneath dung piles to lay their eggs, which provides a food source for their larvae.\n")
    print("Role: Important decomposers, aiding in nutrient recycling and soil aeration through their burrowing activities.\n")
    print("Traits: They are stout, dark-colored beetles known for their burrowing behavior.\n")
    print("Habitat: Found in forests, grasslands, and agricultural areas.\n")
    print("Species: Dor beetles belong to the family Geotrupidae, with several species.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/dorbeetle.wav")))

elif result_bugs[result_recorded]=="Dragonfly":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Dragonfly.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Dragonflies are a common subject in art and symbolism, often representing change and transformation.\n")
    print("Role: Important predators of insect populations, helping control pests and contributing to the health of aquatic ecosystems.\n")
    print("Diet: Carnivorous, feeding on other insects, including mosquitoes and flies.\n")
    print("Habitat: Found near freshwater habitats like ponds, lakes, and rivers.\n")
    print("Traits: Dragonflies have elongated bodies, large multifaceted eyes, and two pairs of strong, transparent wings.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/dragonfly.wav")))

elif result_bugs[result_recorded]=="Dung Beetle":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Dung Beetle.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Dung beetles are divided into three main groups based on their behavior: rollers, tunnelers, and dwellers.\n")
    print("Rollers: These beetles shape dung into balls and roll them to a suitable location for burial. This behavior is often associated with mating, as males offer the dung balls to females as a form of courtship.\n")
    print("Tunnelers: These beetles dig tunnels beneath dung piles and bury pieces of dung within these tunnels to provide food and a nesting site for their larvae.\n")
    print("Dwellers: These beetles live directly in dung piles and lay their eggs there, where the larvae develop.\n")
    print("Role: Important decomposers, aiding in nutrient recycling, soil aeration, and reducing parasitic loads in environments.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/dungbeetle.wav")))

elif result_bugs[result_recorded]=="Grasshopper":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Grasshopper.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Grasshoppers can have significant ecological impacts. In large numbers, they can become pests, causing substantial damage to crops and vegetation.\n")
    print("Role: Important in food chains as prey for many animals, and can influence plant community dynamics through their feeding.\n")
    print("Traits: They have long hind legs adapted for jumping, and short antennae.\n")
    print("Habitat: Found in a variety of habitats including grasslands, forests, and agricultural fields.\n")
    print("Species: Grasshoppers belong to the suborder Caelifera, with over 11,000 species worldwide.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/grasshopper.wav")))

elif result_bugs[result_recorded]=="House Fly":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/House Fly.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("House flies can carry and transmit various pathogens, including bacteria, viruses, and parasites, due to their feeding and breeding habits.\n")
    print("Role: Known as pests due to their potential to spread diseases, but also play a role in decomposition and nutrient recycling.\n")
    print("Traits: Small, with a gray thorax, four dark longitudinal stripes on the back, and slightly hairy bodies.\n")
    print("Habitat: Found worldwide, especially in areas with human activity such as homes, farms, and garbage dumps.\n")
    print("Diet: Omnivorous, feeding on decaying organic matter, food waste, and animal feces.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/housefly.wav")))

elif result_bugs[result_recorded]=="Katydid":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Katydid.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Katydid males produce characteristic mating calls by rubbing their wings together, a behavior known as stridulation. These sounds are often described as katy-did or katy-didn't, which is how they got their common name.\n")
    print("Role: Important in ecosystems as both prey and consumers of plant material, contributing to the balance of plant and insect populations.\n")
    print("Traits: Known for their leaf-like appearance, long antennae.\n")
    print("Diet: Mostly herbivorous, feeding on leaves, flowers, and stems; some species are omnivorous.\n")
    print("Habitat: Found in various habitats including forests, grasslands, and gardens.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/katydid.wav")))

elif result_bugs[result_recorded]=="Locust":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Locust.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Locusts are a type of short-horned grasshopper and distinguished by their ability to undergo dramatic behavioral and physiological changes in response to environmental conditions, particularly crowding.\n")
    print("Role: Can have a significant impact on agriculture due to their swarming behavior, causing extensive crop damage and affecting food security.\n")
    print("Traits: Normally solitary, but can form large, destructive swarms under certain conditions; have powerful hind legs for jumping and flying.\n")
    print("Habitat: Found in various environments, including grasslands, deserts, and agricultural areas.\n")
    print("Diet: Herbivorous, feeding on a wide range of plants and crops.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/locust.wav")))
    
elif result_bugs[result_recorded]=="Long Horn Beetle":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Long Horn Beetle.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Longhorn beetles are of interest to scientists and entomologists due to their diverse behaviors, life cycles, and interactions with their environments.\n")
    print("Role: Important decomposers, aiding in the breakdown of dead wood and recycling nutrients in forest ecosystems.\n")
    print("Traits: Characterized by their long antennae, often longer than their bodies, and elongated bodies.\n")
    print("Diet: Larvae feed on wood, while adults feed on leaves, nectar, and bark.\n")
    print("Habitat: Found in forests, woodlands, and areas with abundant dead or decaying wood.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/longhornbeetle.wav")))

elif result_bugs[result_recorded]=="Mole Cricket":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Mole Cricket.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Mole crickets are insects belonging to the family Gryllotalpidae within the order Orthoptera.\n")
    print("Role: Known for aerating soil through their burrowing activities, but can also be pests due to their feeding on plant roots and damaging crops.\n")
    print("Traits: Known for their burrowing behavior, they have strong forelimbs adapted for digging and are typically brown or tan.\n")
    print("Habitat: Found in moist soil environments, including lawns, gardens, and agricultural fields.\n")
    print("Diet: Omnivorous, feeding on roots, tubers, and other plant material, as well as small insects and larvae.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/molecricket.wav")))

elif result_bugs[result_recorded]=="Mosquito":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Mosquito.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Mosquitoes are small, flying insects known for their ability to feed on the blood of animals, including humans, using specialized mouthparts called proboscis.\n")
    print("Role: While some species serve as pollinators, females are known for their role as vectors of diseases such as malaria, dengue fever, Zika virus, and West Nile virus, posing significant health risks to humans and animals alike.\n")
    print("Traits: Small flying insects with slender bodies, long legs, and a characteristic proboscis for feeding.\n")
    print("Habitat: Found in various habitats worldwide, especially where standing water is present, such as marshes, ponds, and urban areas.\n")
    print("Diet: Females feed on blood to obtain proteins necessary for egg development; males feed on nectar and other plant fluids.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/mosquito.wav")))

elif result_bugs[result_recorded]=="Moth":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Moth.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Moths belong to the order Lepidoptera, which also includes butterflies. They are diverse insects known for their typically dull-colored wings, although some species are brightly colored or patterned.\n")
    print("Role: Moths play important roles in ecosystems as pollinators for many plants, contributors to food webs as prey for birds and other animals, and some species are economically important as pests of crops and stored products.\n")
    print("Traits: Typically have thick bodies, feathery or filamentous antennae (compared to the clubbed antennae of butterflies), and usually rest with their wings spread out.\n")
    print("Habitat: Found in diverse habitats worldwide, including forests, fields, and urban areas.\n")
    print("Diet: As larvae (caterpillars), moths feed on a variety of plant materials; as adults, they primarily feed on nectar.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/moth.wav")))

elif result_bugs[result_recorded]=="Wasp":
    print("Bug:", result_bugs[result_recorded],"\n" )
    import matplotlib.image as mpimg
    plt.figure(figsize=(12,4))
    img = mpimg.imread(os.path.join(base_dir, "Database/image/Wasp.jpg"))
    imgplot = plt.imshow(img)
    plt.show
    print("Wasps are flying insects belonging to the order Hymenoptera, which also includes bees and ants.\n")
    print("Role: Wasps play important roles in ecosystems as predators, helping to control insect populations. Some species are also pollinators, although to a lesser extent than bees. However, some wasps can be pests, particularly those that build nests near human habitation and can sting in defense.\n")
    print("Traits: Typically have slender bodies with a narrow waist, often brightly colored or marked with distinct patterns.\n")
    print("Habitat: Found in various habitats worldwide, including gardens, forests, and urban areas.\n")
    print("Diet: Most adult wasps are predators, feeding on other insects and spiders; some also feed on nectar and sweet substances.\n")
    display(Audio(os.path.join(base_dir, "Database/audio/wasp.wav")))
# Out:
# Bug: Dor Beetle
#
# Dor beetles dig tunnels beneath dung piles to lay their eggs, which provides a food source for their larvae.
#
# Role: Important decomposers, aiding in nutrient recycling and soil aeration through their burrowing activities.
#
# Traits: They are stout, dark-colored beetles known for their burrowing behavior.
#
# Habitat: Found in forests, grasslands, and agricultural areas.
#
# Species: Dor beetles belong to the family Geotrupidae, with several species.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
